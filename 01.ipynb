# %%
from PIL import Image

# %%
dir = 'C:\\Users\\thach\\Anh_TGMT'

# %%
image_path = dir + '\\download.JPG'
print(image_path)
# Out:
# C:\Users\thach\Anh_TGMT\download.JPG

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=170x297>

# %%
size = (500, 500)

# %%
thumbnail = img01.resize(size)

# %%
output = dir + "\\download.jpg"
thumbnail.save(output)

# %%
img01.close()

# %%
thumbnail.close()

# %%
img_thumbnail = Image.open(output)
display(img_thumbnail)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>
